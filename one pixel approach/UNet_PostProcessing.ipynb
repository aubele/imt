# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import os

# %% [markdown]
# # Constants

# %%
# necessary to measure the IMT/LD, taken from the attributes of the used HDF5-files
CM_IN_PIXELS = 266.0282
MM_IN_PIXELS = CM_IN_PIXELS/10
BB_WIDTH = 267

# for creating reproducible results
SEED = 22
np.random.seed = SEED

# values for images
IMG_HEIGHT = 512

# number of classes
NUM_CLASSES = 4

# necessary colours
CLASS_BLACK = (0,0,0)
CLASS_RED = (255,0,0)
CLASS_GREEN = (0,255,0)
CLASS_BLUE = (0,0,255)
# all colours which identify a class
PALETTE = [CLASS_BLACK, CLASS_RED, CLASS_GREEN, CLASS_BLUE]

# directories that contain the results from pre-processing, should already exist
IMAGE_DIRECTORY = "./data/images/"
MASK_DIRECTORY = "./data/masks/"
FILENAME_DIRECTORY = './data/filenames/'
# directories that contain the results from U-Net, should already exist
RESULT_DIRECTORY = './data/results/'
# directories to save the results, should be created
PROBABILITY_DIRECTORY = './data/results/probability/'
AVERAGE_DIRECTORY = './data/results/average/'

# %%
# create the essential directories if they do not exist
if not os.path.exists(PROBABILITY_DIRECTORY):
    os.makedirs(PROBABILITY_DIRECTORY)
if not os.path.exists(AVERAGE_DIRECTORY):
    os.makedirs(AVERAGE_DIRECTORY)

# %% [markdown]
# # Load the results and test data

# %%
# this file can be quite big since it contains float values
results = np.load(RESULT_DIRECTORY + 'results.npy')

# %%
X_test = np.load(FILENAME_DIRECTORY + 'X_test.npy')
y_test = np.load(FILENAME_DIRECTORY + 'y_test.npy')

# %% [markdown]
# # One Hot Encoding and the reverse operation

# %%
def rgbToOnehot(rgbImage, palette=PALETTE):
    """Implements One Hot Encoding (OHE) for RGB images, 
    where each colour represents a class

    Parameters
    ----------
    rgbImage : numpy-array
        RGB-image where One Hot Encoding should be applied
    palette : list
        All colours that define a class
        
    Returns
    -------
    numpy-array
        One Hot encoded RGB image
    """
        
    # create new image
    labelImage = np.zeros((rgbImage.shape[:2]), dtype=np.uint8)
    # label the classes correctly
    labelImage[(rgbImage==palette[0]).all(axis=2)] = 0
    labelImage[(rgbImage==palette[1]).all(axis=2)] = 1
    labelImage[(rgbImage==palette[2]).all(axis=2)] = 2
    labelImage[(rgbImage==palette[3]).all(axis=2)] = 3
    # transform them into binary values
    onehotImage = tf.keras.utils.to_categorical(labelImage, 4)
    return onehotImage

def onehotToRgb(onehotImage, palette=PALETTE):
    """Reverts OHE and gives the image its initial
    colour back

    Parameters
    ----------
    onehotImage : numpy-array
        Image with OHE which should get its colour back
    palette : list
        All colours that define a class
        
    Returns
    -------
    numpy-array
        RGB image
    """
        
    # returns indices of the highest elements
    indices = np.argmax(onehotImage, axis=2)
    # use the initial image shape plus three channels for rgb
    rgbImage = np.zeros(onehotImage.shape[:2]+(3,))
    for i, colours in enumerate(palette):
        # get the colours back
        rgbImage[indices==i] = colours
    return np.uint8(rgbImage)

# %% [markdown]
# # Inspect some predictions

# %%
def createValidationImage(result, mask):
    """Create a validation image for a given prediction
    and mask, the validation image depicts correct predicted 
    pixels in the appropiate colour, missing pixel in pink 
    and excessive pixel in yellow

    Parameters
    ----------
    result : numpy-array
        Prediction result for the validation image
    mask : numpy-array
        Groundtruth/mask for the validation image
        
    Returns
    -------
    numpy-array
        Created validation image
    """
        
    # new validation image
    output = np.zeros(result.shape)
    # iterate over the prediction
    for y, column in enumerate(result):
        for x, pixel in enumerate(column): 
            # draw the correct pixels in the respective colour
            if(pixel == mask[y,x]).all():
                output[y,x] = pixel
            # draw missing pixel in pink
            elif(mask[y,x] != (0,0,0)).any() and (pixel == (0,0,0)).all():
                output[y,x] = (255, 0, 255)
            # draw excessive pixels in yellow
            elif(pixel != (0,0,0)).any() and (mask[y,x] == (0,0,0)).all():
                output[y,x] = (255,140,0)
    return output

# %%
for i, file in enumerate(X_test[0:10]): 
    
    print('File name: ' + file)
    # get all files
    image = np.load(IMAGE_DIRECTORY + file)
    mask = np.load(MASK_DIRECTORY + y_test[i])
    result = onehotToRgb(results[i])
    # create validation image
    validation = createValidationImage(result, mask)
    
    # plot prediction and validation image
    fig = plt.figure(figsize=(20,20))
    
    ax1 = fig.add_subplot(1,2,1)
    ax1.set_title('Prediction')
    ax1.imshow(result)
    ax1.grid(b=None)
    
    ax2 = fig.add_subplot(1,2,2)
    ax2.set_title('Validation image')
    ax2.imshow(validation)
    ax2.grid(b=None)
    
    plt.show()
# Out:
# File name: interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_106.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_178.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_125.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_240.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_186.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_95.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_103.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_248.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_163.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_146.npy
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Thin out the lines with the probability method

# %%
def thinOutLinesProbability(onehotImage, defaultClass=(1.,0.,0.,0.)):
    """Thin out all three lines of the prediction of the
    U-Net model with a probability approach, here all lines
    are shortened to a width of one pixel and only the 
    pixels with the highest probability are used

    Parameters
    ----------
    onehotImage : numpy-array
        Mask as One Hot encoded image (prediction result)
    defaultClass : tuple
        Class which represents the background
        
    Returns
    -------
    numpy-array
        Prediction result with thinned out lines
    """
    
    # lower limit for a majority
    probability = 1/NUM_CLASSES
    # iterate over columns
    for x in range(onehotImage.shape[1]):
        # tuple for highest values (probability value, y-coordinate, x-coordinate)
        highestMAN = (-1, -1, -1)
        highestLIF = (-1, -1, -1)
        highestMAF = (-1, -1, -1)
        # iterate over rows
        for y, pixel in enumerate(onehotImage[:,x]):
            # MAN line
            if pixel[1] > probability:
                # highest probability and top side of the image
                if pixel[1] > highestMAN[0] and y < IMG_HEIGHT/2:
                    # set the old pixel to default
                    onehotImage[highestMAN[1], highestMAN[2]] = defaultClass
                    # current pixel is the new highest probability
                    highestMAN = (pixel[1], y, x)
                else:
                    # lower than the current highest pixel so make it black
                    onehotImage[y,x] = defaultClass
            # LIF line
            if pixel[2] > probability:
                # highest probability and bot side of the image
                if pixel[2] > highestLIF[0] and y > IMG_HEIGHT/2:
                    onehotImage[highestLIF[1], highestLIF[2]] = defaultClass
                    highestLIF = (pixel[2], y, x)
                else:
                    onehotImage[y,x] = defaultClass
            # MAF line
            if pixel[3] > probability:
                # highest probability and bot side of the image
                if pixel[3] > highestMAF[0] and y > IMG_HEIGHT/2:
                    onehotImage[highestMAF[1], highestMAF[2]] = defaultClass
                    highestMAF = (pixel[3], y, x)
                else:
                    onehotImage[y,x] = defaultClass
    return onehotImage

# %% [markdown]
# # Thin out the lines with the average method

# %%
def thinOutLinesAverage(rgbImage, defaultColour=CLASS_BLACK): 
    """Thin out all three lines of the prediction of the
    U-Net model with an average approach, here all lines
    are averaged to a width of one pixel

    Parameters
    ----------
    rgbImage : numpy-array
        Mask as RGB image (prediction result)
    defaultColour : tuple
        Colour which represents the background
        
    Returns
    -------
    numpy-array
        Prediction result with thinned out lines
    """
    
    for x in range(rgbImage.shape[1]):
        # all pixels of the respective colour of this column
        redPixels = []
        greenPixels = []
        bluePixels = []
        # the average pixel of the respective colour for this column
        averageRed = []
        averageGreen = []
        averageBlue = []
        
        for y, pixel in enumerate(rgbImage[:,x]):
            # red line -> MAN
            if (np.array_equal(pixel, CLASS_RED)):
                # has to be on top of the image
                if (y > IMG_HEIGHT/2):
                    # else reset it
                    rgbImage[y,x] = defaultColour
                else:
                    # valid pixel so append it
                    redPixels.append([y,x])
                    # reset the current pixel
                    rgbImage[y,x] = defaultColour
            # green line -> LIF
            elif (np.array_equal(pixel, CLASS_GREEN)):
                # has to be on bot of the image
                if (y < IMG_HEIGHT/2):
                    rgbImage[y,x] = defaultColour
                else:
                    greenPixels.append([y,x])
                    rgbImage[y,x] = defaultColour
            # blue line -> MAF
            elif (np.array_equal(pixel, CLASS_BLUE)):
                # has to be on bot of the image
                if(y < IMG_HEIGHT/2):
                    rgbImage[y,x] = defaultColour
                else:   
                    bluePixels.append([y,x])
                    rgbImage[y,x] = defaultColour
                    
        # when there are pixels
        if (len(redPixels) > 0):
            # average them
            averageRed = np.mean(redPixels, axis=0)
            # the average coordinates receive the colour for the class
            rgbImage[int(round(averageRed[0])),int(round(averageRed[1]))] = CLASS_RED
        if (len(greenPixels) > 0):        
            averageGreen = np.mean(greenPixels, axis=0)
            rgbImage[int(round(averageGreen[0])),int(round(averageGreen[1]))] = CLASS_GREEN   
        if (len(bluePixels) > 0):        
            averageBlue = np.mean(bluePixels, axis=0)
            rgbImage[int(round(averageBlue[0])),int(round(averageBlue[1]))] = CLASS_BLUE    
        
    return rgbImage

# %% [markdown]
# # Helper methods for linear interpolation

# %%
def findNextPixel(rgbImage, colour, currentX):    
    """Finds the next pixel which has the wished colour 
    starting from the given x coordinate

    Parameters
    ----------
    rgbImage : numpy-array
        Mask as RGB image (prediction result)
    colour : tuple
        Colour that the next pixel should have
    currentX : int
        X-coordinate where the iteration starts
        
    Returns
    -------
    tuple
        Coordinates of the next pixel which has
        the wished colour
    """
    
    # iterate over the image
    for x in range(currentX, rgbImage.shape[1]):
        for y, pixel in enumerate(rgbImage[:,x]):
            # if it is the given colour return it
            if (np.array_equal(pixel, colour)):
                return (y,x)

def fillHole(rgbImage, lastPixel, colour, currentX):    
    """Applys linear interpolation at the given x-coordinate 
    of the given image, takes care of three cases: hole at 
    the beginning, hole at the end and hole in the middle 
    of the line

    Parameters
    ----------
    rgbImage : numpy-array
        Mask as RGB image (prediction result)
    lastPixel : tuple
        Coordinates of the lastly processed pixel
    colour : tuple
        Colour that the interpolated pixel should have
    currentX : int
        X-coordinate where the iteration starts
        
    Returns
    -------
    tuple
        Coordinates of the next pixel which has
        the wished colour
    """
    
    # find the next pixel               
    nextPixel = findNextPixel(rgbImage, colour, currentX)
    # no last pixel
    if not lastPixel:
        # hole at the start -> use current x-coord and y-coord where the next pixel is
        lastPixel = (nextPixel[0], currentX)
    # no next pixel
    if not nextPixel:
        # hole at the end -> use current x-coord and the y-coord where the last pixel is
        rgbImage[lastPixel[0], currentX] = colour
        # return the image and the newly created pixel
        return rgbImage, (lastPixel[0], currentX)
    
    # how far are they separated
    distance = nextPixel[1] - lastPixel[1]
    # get all x-coordinates for the whole distance
    x_new = []
    for i in range(distance):
        x_new.append(currentX + i)
    # interpolation
    y_new = np.interp(x_new, [lastPixel[1],nextPixel[1]], [lastPixel[0],nextPixel[0]])
    # round and cast to int
    y_new = np.around(y_new, 0)
    y_new = np.asarray(y_new, dtype=np.uint16)
    
    # fill in the interpolated values in the image
    for i, y in enumerate(y_new):
        rgbImage[y, x_new[i]] = colour
    
    # return the filled image, and the current interpolated pixel so the imt can be calculated instantly
    return rgbImage, (y_new[0],x_new[0])

# %% [markdown]
# # Measure the IMT and LD

# %%
def measureIMT(rgbImageOriginal, interpolation=False):
    """Measures the IMT and LD of the given mask and applies 
    interpolation if wished, this method also calculates 
    two safety variable to quickly see if holes are present
    

    Parameters
    ----------
    rgbImageOriginal : numpy-array
        Mask as RGB image (prediction result)
    interpolation : bool
        Determines if interpolation should be used
        
    Returns
    -------
    float
        Measured IMT value of the image
    float
        Measured LD value of the image
    float
        Safety variable to signalise if columns are missing
        for the measurement of IMT
    float
        Safety variable to signalise if columns are missing
        for the measurement of LD
    numpy-array
        Edited mask (prediction result), which only changes if 
        interpolation is used
    """
    
    # copy the image since the original image needs to be maintained
    rgbImage = rgbImageOriginal.copy()
    # all IMT/LD values
    imts = [] 
    lds = []
    # safety variables to detect holes in the predictions
    safetyIMT = 0
    safetyLD = 0
    # the lastly found pixel
    lastRed = ()
    lastGreen = ()
    lastBlue = ()
    
    for x in range(rgbImage.shape[1]):
        # amount of found pixel
        redFound = 0
        greenFound = 0
        blueFound = 0
        # current coordinates of the pixel
        redPixel = ()
        greenPixel = ()
        bluePixel = ()
        
        for y, pixel in enumerate(rgbImage[:,x]):
            # red line -> MAN
            if (np.array_equal(pixel, (255,0,0))):
                # current pixel
                redPixel = (y,x)
                # raise the amount of found pixel
                redFound += 1
            # green line -> LIF
            elif (np.array_equal(pixel, (0,255,0))):
                greenPixel = (y,x)
                greenFound += 1
            # blue line- > MAF
            elif (np.array_equal(pixel, (0,0,255))):
                bluePixel = (y,x)
                blueFound += 1
                
        # now we got the pixels so we can measure the IMT
        
        # when there are too many pixels cancel the measuring
        if (redFound > 1 or greenFound > 1 or blueFound > 1):
            print('Error in column ' + str(x) + ': Too many pixels - red pixels: ' + str(redFound) 
                  + ' - green pixels: ' + str(greenFound) + ' - blue pixels: ' + str(blueFound))
            continue

        # no colours found so just continue
        if (redFound < 1 and greenFound < 1 and blueFound < 1):
            continue
        # interpolation
        elif (interpolation):
            # no red found so fill the hole
            if (redFound < 1):
                # call helper method
                rgbImage, redPixel = fillHole(rgbImage, lastRed, CLASS_RED, x)
                # new pixel so increase the amount of found pixels
                redFound += 1
            else:
                # else it is the new lastly processed pixel
                lastRed = redPixel
            if (greenFound < 1):
                rgbImage, greenPixel = fillHole(rgbImage, lastGreen, CLASS_GREEN, x)
                greenFound += 1
            else:
                lastGreen = greenPixel
            if (blueFound < 1):
                rgbImage, bluePixel = fillHole(rgbImage, lastBlue, CLASS_BLUE, x)
                blueFound += 1
            else:
                lastBlue = bluePixel
                      
        # LIF (green) and MAF (blue) -> measure the imt
        if (greenFound == 1 and blueFound == 1):
            # calculate imt
            imt = bluePixel[0] - greenPixel[0]
            # append it in the list
            imts.append(imt)
            # raise safety variable
            safetyIMT += 1
        # MAN (red) and MAF (blue) -> measure the ld
        if (redFound == 1 and blueFound == 1):
            # calculate ld
            ld = bluePixel[0] - redPixel[0]
            # append it in the list
            lds.append(ld)
            # raise safety variable
            safetyLD += 1
    
    # calculate the average imt and ld in mm
    finalIMT = (sum(imts)/len(imts))/MM_IN_PIXELS
    finalLD = (sum(lds)/len(lds))/MM_IN_PIXELS
    # calculate the precentage of how many columns had a valid IMT/LD value
    safetyIMT = safetyIMT / BB_WIDTH
    safetyLD = safetyLD / BB_WIDTH
    
    return finalIMT, finalLD, safetyIMT, safetyLD, rgbImage

# %% [markdown]
# # Main method to control the post-processing

# %%
def createResultDictionary(filenameImage, filenameMask, prediction, 
                           size='1px', method='probability', interpolation=False):
    """Central method to control all post-processing steps,
    loads the image, mask and prediction result and edits 
    the lines with the appropiate methods, finally measures
    the IMT/LD and calculates the differences to the real
    IMT/LD values

    Parameters
    ----------
    filenameImage : string
        Path to the image
    filenameMask : string
        Path to the mask
    prediction : numpy-array
        Mask as RGB image (prediction result)
    size : string
        Size of the lines in the mask and prediction result
        (either 1px or 3px)
    method : string
        Specifies the kind of editing method to thin out 
        the lines (either probability or average)
    interpolaton : bool
        Determines if interpolation should be used
        
    Returns
    -------
    dictionary
        A dictionary with following objects: filename, image, 
        ground truth, prediction, imt from ground truth, 
        imt from prediction, differences
    """
    
    # get image
    image = np.load(IMAGE_DIRECTORY + filenameImage)
    # get the groundtruth/mask
    mask = np.load(MASK_DIRECTORY + filenameMask)
    # edit the line for the three pixel approach
    if (size=='3px'):
        mask = thinOutLinesAverage(mask)
    
    # edit the predictions -> probability
    if (method == 'probability'):
        # thin out the lines
        result = thinOutLinesProbability(prediction)
        # revert OHE
        result = onehotToRgb(result)
        # create file name
        filenameResult = filenameImage.rsplit('.', 1)[0] + '_probability.npy'
        # save result
        np.save(PROBABILITY_DIRECTORY + filenameResult, result)
    # edit the predictions -> average
    elif (method == 'average'):
        # revert OHE
        result = onehotToRgb(prediction)
        # thin out the lines
        result = thinOutLinesAverage(result)
        # create file name
        filenameResult = filenameImage.rsplit('.', 1)[0] + '_average.npy'
        # save result
        np.save(AVERAGE_DIRECTORY + filenameResult, result)
    else:
        print('No kind of result creation specified - skipping')
        
    # measure imt/ld from the mask
    trueIMT, trueLD, trueSafetyIMT, trueSafetyLD, _ = measureIMT(mask, interpolation=interpolation)
    # measure imt/ld from the prediction
    imt, ld, safetyIMT, safetyLD, _ = measureIMT(result, interpolation=interpolation)
    
    # get the differences
    diffIMT = trueIMT-imt
    diffLD = trueLD-ld
    
    return {'image_file':filenameImage, 'mask_file': filenameMask, 'result_file':filenameResult,
           'trueIMT_tuple':(trueIMT, trueLD, trueSafetyIMT, trueSafetyLD), 
            'imt_tuple':(imt, ld, safetyIMT, safetyLD), 'imt_diff':diffIMT, 'ld_diff':diffLD}

# %% [markdown]
# # Apply post-processing to each prediction result

# %%
# the execution of this cell may take a long time

# list for all results
allResults = []
# wished post-processing method, either probability or average
method = 'probability'
# load the results again so they are unedited in case they were edited already
results = np.load(RESULT_DIRECTORY + 'results.npy')

# apply post-processing, should be done once with probabilty and once with average
for i, prediction in enumerate(results):
    allResults.append(createResultDictionary(X_test[i], y_test[i], prediction, '1px', method, False))
    print (str(i+1) + ' out of ' + str(len(results)) + ' images done', end='\r')
    
# the created files are not as big as the result from the U-Net model since int-values are used for all images

# save the results for the probability method
if (method == 'probability'):
    np.save(RESULT_DIRECTORY + 'allResults_probability.npy', allResults)
# save the results for the average method
elif (method == 'average'):
    np.save(RESULT_DIRECTORY + 'allResults_average.npy', allResults)
# Out:
# 107 out of 107 images done

# %% [markdown]
# # Achieved results

# %%
# load all edited results
resultsProb = np.load(RESULT_DIRECTORY + 'allResults_probability.npy', allow_pickle=True)
resultsAver = np.load(RESULT_DIRECTORY + 'allResults_average.npy', allow_pickle=True)

# %%
# calculate average values
avgIMTProb = (sum([abs(res['imt_diff']) for res in resultsProb])/len(resultsProb))
avgLDProb = (sum([abs(res['ld_diff']) for res in resultsProb])/len(resultsProb))

avgIMTAver = (sum([abs(res['imt_diff']) for res in resultsAver])/len(resultsAver))
avgLDAver = (sum([abs(res['ld_diff']) for res in resultsAver])/len(resultsAver))

# %%
print('Probabilty approach - Number of Images: ' + str(len(resultsProb)))
print('Average approach - Number of Images: ' + str(len(resultsAver)))
print('')
print('Probabilty approach - IMT differences: ' + str(avgIMTProb))
print('Probabilty approach - LD differences: ' + str(avgLDProb))
print('')
print('Average approach - IMT differences: ' + str(avgIMTAver))
print('Average approach - LD differences: ' + str(avgLDAver))
# Out:
# Probabilty approach - Number of Images: 107
# Average approach - Number of Images: 107
#
# Probabilty approach - IMT differences: 0.008345256855787542
# Probabilty approach - LD differences: 0.016884214739946005
#
# Average approach - IMT differences: 0.008496184673904018
# Average approach - LD differences: 0.016594921987277564

# %% [markdown]
# # Add interpolation

# %%
def addInterpolationToResult(resultList, directory):
    """This method collects all edited predicitons with 
    holes and uses linear interpolation on them, also it
    inserts the results of the interpolation in the 
    appropiate dictionary as a new entry

    Parameters
    ----------
    resultList : list
        List of dictionaries with all results of the
        post-processing
    directory : string
        Path to the directory where the results are saved
    """
    interpolation = []
    # if holes are detected append the results in a list
    for res in resultList:
        if (res['imt_tuple'][2] < 1.0 or res['imt_tuple'][3] < 1.0):
            interpolation.append(res)
    # add interpolation to all appended results
    for i, res in enumerate(interpolation):
        interpolation[i]['interpolation'] = measureIMT(np.load(directory + res['result_file']), True)

# %% [markdown]
# ## Add interpolation to the results (probability method)

# %%
# create and save interpolation result
addInterpolationToResult(resultsProb, PROBABILITY_DIRECTORY)
np.save(RESULT_DIRECTORY + 'allResults_probability_with_interpolation.npy', resultsProb)

# %% [markdown]
# ## Evaluate interpolation results (probability method)

# %%
# load results with interpolation
resultsProbInter = np.load(RESULT_DIRECTORY + 'allResults_probability_with_interpolation.npy', allow_pickle = True)

# %%
# find all results with interpolation
interpolationProb = []
for res in resultsProbInter:
    if 'interpolation' in res:
        interpolationProb.append(res)

# %%
# check if interpolation was successful
# interpolation is only unsuccessful if one or more predicted lines extend over 
# too much columns or if all three lines miss a pixel at the same column
for tup in interpolationProb:
    if (tup['interpolation'][2] != 1.0 and tup['interpolation'][3] != 1.0):
        print('Interpolation unsuccessful for file: ' + tup['image_file'])

# %%
# collect the differences before and after interpolation
interpolationIMTDiff = 0
interpolationLDDiff = 0
imtDiff = 0
ldDiff = 0
for tup in interpolationProb:
    interIMTDiff = tup['trueIMT_tuple'][0] - tup['interpolation'][0]
    interLDDiff = tup['trueIMT_tuple'][1] - tup['interpolation'][1]
    
    imtDiff += (abs(tup['imt_diff']))
    ldDiff += (abs(tup['ld_diff']))    
    
    interpolationIMTDiff += (abs(interIMTDiff))
    interpolationLDDiff += (abs(interLDDiff))

# %%
print('Probability: ')
print('IMT from images with holes without Interpolation: ' + str(imtDiff/len(interpolationProb)))
print('IMT from images with holes with Interpolation: ' + str(interpolationIMTDiff/len(interpolationProb)))
print('')
print('LD from images with holes without Interpolation: ' + str(ldDiff/len(interpolationProb)))
print('LD from images with holes with Interpolation: ' + str(interpolationLDDiff/len(interpolationProb)))
# Out:
# Probability:
# IMT from images with holes without Interpolation: 0.008398750375086859
# IMT from images with holes with Interpolation: 0.027890514241762254
#
# LD from images with holes without Interpolation: 0.01695584025563371
# LD from images with holes with Interpolation: 0.011687941600779232

# %% [markdown]
# ## Add interpolation to the results (average method)

# %%
# create and save interpolation result
addInterpolationToResult(resultsAver, AVERAGE_DIRECTORY)
np.save(RESULT_DIRECTORY + 'allResults_average_with_interpolation.npy', resultsAver)

# %% [markdown]
# ## Evaluate interpolation results (average method)

# %%
# load results with interpolation
resultsAverInter = np.load(RESULT_DIRECTORY + 'allResults_average_with_interpolation.npy', allow_pickle = True)

# %%
# find all results with interpolation
interpolationAver = []
for res in resultsAverInter:
    if 'interpolation' in res:
        interpolationAver.append(res)

# %%
# check if interpolation was successful
# interpolation is only unsuccessful if one or more predicted lines extend over 
# too much columns or if all three lines miss a pixel at the same column
for tup in interpolationAver:
    if (tup['interpolation'][2] != 1.0 and tup['interpolation'][3] != 1.0):
        print('Interpolation unsuccesful for file: ' + tup['image_file'])

# %%
# collect the differences before and after interpolation
interpolationIMTDiff = 0
interpolationLDDiff = 0
imtDiff = 0
ldDiff = 0
for tup in interpolationAver:
    interIMTDiff = tup['trueIMT_tuple'][0] - tup['interpolation'][0]
    interLDDiff = tup['trueIMT_tuple'][1] - tup['interpolation'][1]
    
    imtDiff += (abs(tup['imt_diff']))
    ldDiff += (abs(tup['ld_diff']))    
    
    interpolationIMTDiff += (abs(interIMTDiff))
    interpolationLDDiff += (abs(interLDDiff))

# %%
print('Average: ')
print('IMT from images with holes without Interpolation: ' + str(imtDiff/len(interpolationAver)))
print('IMT from images with holes with Interpolation: ' + str(interpolationIMTDiff/len(interpolationAver)))
print('')
print('LD from images with holes without Interpolation: ' + str(ldDiff/len(interpolationAver)))
print('LD from images with holes with Interpolation: ' + str(interpolationLDDiff/len(interpolationAver)))
# Out:
# Average:
# IMT from images with holes without Interpolation: 0.008573681010142378
# IMT from images with holes with Interpolation: 0.03402301433565782
#
# LD from images with holes without Interpolation: 0.016679756422240347
# LD from images with holes with Interpolation: 0.011691648185903404

# %% [markdown]
# # Further inspect the results

# %%
# specify the array to inspect
allRes = resultsProb.copy()
# specify the result directory based on the post-processing method
resultDirecotry = PROBABILITY_DIRECTORY
# sort the values to get bad/good results
allRes = sorted(allRes, key = lambda i: abs(i['imt_diff']), reverse=True)

# %%
# list all values
for i, ele in enumerate(allRes):
    print(i,abs(ele['imt_diff']))
# Out:
# 0 0.06164666528755214
# 1 0.06153198919116187
# 2 0.036561992653093234
# 3 0.03469819234494209
# 4 0.028291901361807925
# 5 0.025168855458626793
# 6 0.02489661802163634
# 7 0.024180084177778616
# 8 0.02076303679402347
# 9 0.020399678895193785
# 10 0.020337509914422403
# 11 0.018833430842493226
# 12 0.017651189113870203
# 13 0.016011952186345657
# 14 0.015872885806034298
# 15 0.015142549738168198
# 16 0.015045632704506096
# 17 0.014826579999838718
# 18 0.014802696572963292
# 19 0.014641797697170111
# 20 0.013722410446876943
# 21 0.0135806193304161
# 22 0.013325392387647739
# 23 0.012144784080075022
# 24 0.01213434129445512
# 25 0.010825317356702557
# 26 0.010277415691282932
# 27 0.009964759921275879
# 28 0.009950427653380944
# 29 0.009908886280918683
# 30 0.009199301456049747
# 31 0.009179704282089474
# 32 0.009175664329631017
# 33 0.00870133806703699
# 34 0.008510302176107265
# 35 0.008252255802694952
# 36 0.008165617946498727
# 37 0.007884044913860855
# 38 0.007839484044016798
# 39 0.007464427959377851
# 40 0.006357919076963481
# 41 0.006335393234352504
# 42 0.006253513210217165
# 43 0.006194606718033624
# 44 0.005785329102008907
# 45 0.00577224716907665
# 46 0.005107480761194827
# 47 0.005068314587481915
# 48 0.005047262398125807
# 49 0.0050252964852735005
# 50 0.004786741554844043
# 51 0.0046459550385251625
# 52 0.0046459550385251625
# 53 0.004505168522206282
# 54 0.004431322009872951
# 55 0.004364382005887291
# 56 0.004348364378282232
# 57 0.0042347102145409155
# 58 0.004012415715089812
# 59 0.003857400774249342
# 60 0.003801235940611436
# 61 0.003801235940611436
# 62 0.0037651520015549167
# 63 0.003685294103642822
# 64 0.0034265356403696545
# 65 0.003356878498479765
# 66 0.003309811308177424
# 67 0.003099452771479716
# 68 0.003097303359016701
# 69 0.003097303359016701
# 70 0.002934816665370543
# 71 0.0026749438100599487
# 72 0.0026749438100599487
# 73 0.0026749438100599487
# 74 0.0025733234674537586
# 75 0.0025341572937410684
# 76 0.002393370777421966
# 77 0.002376081205242464
# 78 0.0022525842611030855
# 79 0.002123165600139143
# 80 0.0020532890626775435
# 81 0.0019742353471594587
# 82 0.001862354415040568
# 83 0.0018302247121463333
# 84 0.0018302247121462223
# 85 0.0018302247121461113
# 86 0.0016823988700114256
# 87 0.0016223969975801555
# 88 0.0015486516795083505
# 89 0.0015300572339568275
# 90 0.001410773975510038
# 91 0.001407865163189581
# 92 0.001405715750726566
# 93 0.0011069023708188963
# 94 0.0010898818246070086
# 95 0.0009151123560731111
# 96 0.0008447190979136154
# 97 0.0007659740972606466
# 98 0.0007039325815948461
# 99 0.0006408529086985304
# 100 0.0005631460652758546
# 101 0.0005631460652757436
# 102 0.0004927528071162479
# 103 0.00040595209780691643
# 104 0.00039420224569297613
# 105 0.0002815730326378718
# 106 0.0002418775863074485

# %%
# plot some examples, here: ultrasound image and mask
# only plot two images next to each other else the view is too small
for index in range(0,10):
    print('File name: ' + allRes[index]['image_file'])
    print('Index: ' + str(index))
    print('IMT-Diff: ' + str(allRes[index]['imt_diff']))
    print('LD-Diff: ' + str(allRes[index]['ld_diff']))
    
    image = np.load(IMAGE_DIRECTORY + allRes[index]['image_file'])
    mask = np.load(MASK_DIRECTORY + allRes[index]['mask_file'])
    result = np.load(resultDirecotry + allRes[index]['result_file'])
    
    fig = plt.figure(figsize=(30,30))
    
    ax1 = fig.add_subplot(1,2,1)
    ax1.set_title('Ultrasound Image',fontsize=25)
    ax1.imshow(image)
    plt.axis('off')
    
    ax2 = fig.add_subplot(1,2,2)
    ax2.set_title('Groundtruth/Mask',fontsize=25)
    ax2.imshow(mask)
    plt.axis('off')
    
    plt.show()
# Out:
# File name: interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_122.npy
# Index: 0
# IMT-Diff: -0.06164666528755214
# LD-Diff: -0.05882468191721113
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_185.npy
# Index: 1
# IMT-Diff: 0.06153198919116187
# LD-Diff: 0.11237750382900913
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_184.npy
# Index: 2
# IMT-Diff: 0.036561992653093234
# LD-Diff: 0.09345268166735199
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_191.npy
# Index: 3
# IMT-Diff: 0.03469819234494209
# LD-Diff: 0.02336343327773882
# File name: interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_130.npy
# Index: 4
# IMT-Diff: -0.028291901361807925
# LD-Diff: -0.06384065144279827
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_169.npy
# Index: 5
# IMT-Diff: 0.025168855458626793
# LD-Diff: 0.10128709933420943
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_250.npy
# Index: 6
# IMT-Diff: -0.02489661802163634
# LD-Diff: -0.00038690970671773073
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_253.npy
# Index: 7
# IMT-Diff: -0.024180084177778616
# LD-Diff: 0.009861670273966006
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_208.npy
# Index: 8
# IMT-Diff: 0.02076303679402347
# LD-Diff: -0.024978640862678425
# File name: interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_178.npy
# Index: 9
# IMT-Diff: -0.020399678895193785
# LD-Diff: -0.04906573798966729

# %%
# plot some examples, here: prediction and validation image
# only plot two images next to each other else the view is too small
for index in range(0,10):
    print('File name: ' + allRes[index]['image_file'])
    print('Index: ' + str(index))
    print('IMT-Diff: ' + str(allRes[index]['imt_diff']))
    print('LD-Diff: ' + str(allRes[index]['ld_diff']))
    
    image = np.load(IMAGE_DIRECTORY + allRes[index]['image_file'])
    mask = np.load(MASK_DIRECTORY + allRes[index]['mask_file'])
    result = np.load(resultDirecotry + allRes[index]['result_file'])
    
    fig = plt.figure(figsize=(30,30))
    
    ax1 = fig.add_subplot(1,2,1)
    ax1.set_title('Prediction',fontsize=25)
    ax1.imshow(result)
    plt.axis('off')
    
    mask = thinOutLinesAverage(mask)
    ax2 = fig.add_subplot(1,2,2)
    ax2.set_title('Validation image', fontsize=25)
    ax2.imshow(createValidationImage(result, mask))
    plt.axis('off')
    
    plt.show()
# Out:
# File name: interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_122.npy
# Index: 0
# IMT-Diff: -0.06164666528755214
# LD-Diff: -0.05882468191721113
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_185.npy
# Index: 1
# IMT-Diff: 0.06153198919116187
# LD-Diff: 0.11237750382900913
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_184.npy
# Index: 2
# IMT-Diff: 0.036561992653093234
# LD-Diff: 0.09345268166735199
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_191.npy
# Index: 3
# IMT-Diff: 0.03469819234494209
# LD-Diff: 0.02336343327773882
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_130.npy
# Index: 4
# IMT-Diff: -0.028291901361807925
# LD-Diff: -0.06384065144279827
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_169.npy
# Index: 5
# IMT-Diff: 0.025168855458626793
# LD-Diff: 0.10128709933420943
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_250.npy
# Index: 6
# IMT-Diff: -0.02489661802163634
# LD-Diff: -0.00038690970671773073
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_253.npy
# Index: 7
# IMT-Diff: -0.024180084177778616
# LD-Diff: 0.009861670273966006
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_208.npy
# Index: 8
# IMT-Diff: 0.02076303679402347
# LD-Diff: -0.024978640862678425
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# File name: interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_178.npy
# Index: 9
# IMT-Diff: -0.020399678895193785
# LD-Diff: -0.04906573798966729
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Uncommented experiments and examinations

# %%
resultsProb = np.load(RESULT_DIRECTORY + 'allResults_probability.npy', allow_pickle=True)
resultsAver = np.load(RESULT_DIRECTORY + 'allResults_average.npy', allow_pickle=True)

# %%
resultsProb
# Out:
# array([{'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_106.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_106_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_106_probability.npy', 'trueIMT_tuple': (0.7664417948403301, 7.44859221888636, 1.0, 1.0), 'imt_tuple': (0.7668359970860231, 7.466199117969906, 0.9363295880149812, 0.9213483146067416), 'imt_diff': -0.00039420224569297613, 'ld_diff': -0.017606899083546068},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_178.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_178_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_178_probability.npy', 'trueIMT_tuple': (0.7579946038611935, 7.366654466388735, 1.0, 1.0), 'imt_tuple': (0.7783942827563873, 7.4157202043784025, 0.550561797752809, 0.48314606741573035), 'imt_diff': -0.020399678895193785, 'ld_diff': -0.04906573798966729},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_125.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_125_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_125_probability.npy', 'trueIMT_tuple': (0.7409594353866013, 7.8012624422653145, 1.0, 1.0), 'imt_tuple': (0.7412013129729087, 7.838780954668591, 0.9962546816479401, 0.7228464419475655), 'imt_diff': -0.0002418775863074485, 'ld_diff': -0.03751851240327664},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_240.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_240_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_240_probability.npy', 'trueIMT_tuple': (0.8587977495455573, 6.8097030078309935, 1.0, 1.0), 'imt_tuple': (0.8674990876125943, 6.802455417937651, 0.8651685393258427, 0.6329588014981273), 'imt_diff': -0.00870133806703699, 'ld_diff': 0.007247589893342621},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_186.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_186_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_186_probability.npy', 'trueIMT_tuple': (0.6224171886460507, 7.608807274457319, 1.0, 1.0), 'imt_tuple': (0.6179120201238444, 7.607815421909973, 1.0, 0.9138576779026217), 'imt_diff': 0.004505168522206282, 'ld_diff': 0.000991852547345573},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_95.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_95_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_95_probability.npy', 'trueIMT_tuple': (0.7796757273743109, 7.370033342780389, 1.0, 1.0), 'imt_tuple': (0.765953316927434, 7.375346708375355, 0.9250936329588015, 0.8951310861423221), 'imt_diff': 0.013722410446876943, 'ld_diff': -0.00531336559496598},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_103.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_103_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_103_probability.npy', 'trueIMT_tuple': (0.7320898848585079, 7.9579578349282984, 1.0, 1.0), 'imt_tuple': (0.733004997214581, 7.981766594669287, 0.9887640449438202, 0.599250936329588), 'imt_diff': -0.0009151123560731111, 'ld_diff': -0.023808759740988172},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_248.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_248_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_248_probability.npy', 'trueIMT_tuple': (0.861895052904574, 6.767607839451629, 1.0, 1.0), 'imt_tuple': (0.871845480557955, 6.76011604367572, 0.9288389513108615, 0.6479400749063671), 'imt_diff': -0.009950427653380944, 'ld_diff': 0.0074917957759090825},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_163.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_163_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_163_probability.npy', 'trueIMT_tuple': (0.7846032554454739, 7.603457386837199, 1.0, 1.0), 'imt_tuple': (0.7831953902822844, 7.593912243870405, 1.0, 0.5767790262172284), 'imt_diff': 0.001407865163189581, 'ld_diff': 0.009545142966794096},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_146.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_146_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_146_probability.npy', 'trueIMT_tuple': (0.7739034802052341, 7.586281431846288, 1.0, 1.0), 'imt_tuple': (0.7535659702908117, 7.589170371161153, 0.5580524344569289, 0.5617977528089888), 'imt_diff': 0.020337509914422403, 'ld_diff': -0.002888939314864558},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_129.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_129_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_129_probability.npy', 'trueIMT_tuple': (0.6141107841832328, 7.233892781499971, 1.0, 1.0), 'imt_tuple': (0.6148147167648277, 7.236713293255206, 1.0, 0.9925093632958801), 'imt_diff': -0.0007039325815948461, 'ld_diff': -0.002820511755234456},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_174.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_174_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_174_probability.npy', 'trueIMT_tuple': (0.799245053142644, 7.445776488559981, 1.0, 1.0), 'imt_tuple': (0.7998859060513426, 7.4717543795020696, 0.5767790262172284, 0.5692883895131086), 'imt_diff': -0.0006408529086985304, 'ld_diff': -0.025977890942088244},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_166.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_166_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_166_probability.npy', 'trueIMT_tuple': (0.7753113453684236, 7.468302331171012, 1.0, 1.0), 'imt_tuple': (0.7874456866628787, 7.4847059715581175, 0.651685393258427, 0.6554307116104869), 'imt_diff': -0.01213434129445512, 'ld_diff': -0.01640364038710551},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_149.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_149_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_149_probability.npy', 'trueIMT_tuple': (0.6194606718033528, 7.658786487750543, 1.0, 1.0), 'imt_tuple': (0.6167857279932929, 7.649494577673494, 1.0, 1.0), 'imt_diff': 0.0026749438100599487, 'ld_diff': 0.009291910077049437},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_102.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_102_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_102_probability.npy', 'trueIMT_tuple': (0.7765784240152942, 7.351027163077332, 1.0, 1.0), 'imt_tuple': (0.7673791225592445, 7.361425496220131, 0.9850187265917603, 0.9288389513108615), 'imt_diff': 0.009199301456049747, 'ld_diff': -0.010398333142799032},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_154.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_154_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_154_probability.npy', 'trueIMT_tuple': (0.7906570756471886, 7.662728510207474, 1.0, 1.0), 'imt_tuple': (0.7864223654326477, 7.674170985330903, 0.9962546816479401, 0.7752808988764045), 'imt_diff': 0.0042347102145409155, 'ld_diff': -0.011442475123429219},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_97.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_97_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_97_probability.npy', 'trueIMT_tuple': (0.7277255028526206, 8.026943227924582, 1.0, 1.0), 'imt_tuple': (0.7291312186033472, 8.027015072590126, 0.9812734082397003, 0.7265917602996255), 'imt_diff': -0.001405715750726566, 'ld_diff': -7.184466554477353e-05},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_229.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_229_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_229_probability.npy', 'trueIMT_tuple': (0.8464085361094902, 6.833777502121533, 1.0, 1.0), 'imt_tuple': (0.8640597252233604, 6.806504807468615, 0.8277153558052435, 0.6741573033707865), 'imt_diff': -0.017651189113870203, 'ld_diff': 0.02727269465291826},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_99.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_99_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_99_probability.npy', 'trueIMT_tuple': (0.731526738793232, 8.005262104411464, 1.0, 1.0), 'imt_tuple': (0.7320898848585079, 8.00690058307071, 1.0, 0.6104868913857678), 'imt_diff': -0.0005631460652758546, 'ld_diff': -0.0016384786592453793},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_157.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_157_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_157_probability.npy', 'trueIMT_tuple': (0.6184751661891201, 7.736500644758601, 1.0, 1.0), 'imt_tuple': (0.6146739302485087, 7.72555573534877, 1.0, 0.9550561797752809), 'imt_diff': 0.003801235940611436, 'ld_diff': 0.010944909409830395},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_253.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_253_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_253_probability.npy', 'trueIMT_tuple': (0.8497874125011449, 6.733678289018764, 1.0, 1.0), 'imt_tuple': (0.8739674966789235, 6.723816618744798, 0.8838951310861424, 0.5580524344569289), 'imt_diff': -0.024180084177778616, 'ld_diff': 0.009861670273966006},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_55.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_55_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_55_probability.npy', 'trueIMT_tuple': (0.7399739297723688, 8.079738171544186, 1.0, 1.0), 'imt_tuple': (0.7356095477664815, 8.073730529319823, 1.0, 0.9363295880149812), 'imt_diff': 0.004364382005887291, 'ld_diff': 0.006007642224362897},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_118.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_118_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_118_probability.npy', 'trueIMT_tuple': (0.766582581356649, 7.6875069370796085, 1.0, 1.0), 'imt_tuple': (0.7658166072593884, 7.721018375832544, 0.8838951310861424, 0.8689138576779026), 'imt_diff': 0.0007659740972606466, 'ld_diff': -0.03351143875293516},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_229.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_229_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_229_probability.npy', 'trueIMT_tuple': (0.6198830313523096, 7.295979635196625, 1.0, 1.0), 'imt_tuple': (0.6176304470912065, 7.287291347308293, 1.0, 0.898876404494382), 'imt_diff': 0.0022525842611030855, 'ld_diff': 0.008688287888332091},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_111.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_111_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_111_probability.npy', 'trueIMT_tuple': (0.7789717947927162, 7.626687162029825, 1.0, 1.0), 'imt_tuple': (0.772718281582499, 7.639456735675947, 0.8951310861423221, 0.8913857677902621), 'imt_diff': 0.006253513210217165, 'ld_diff': -0.01276957364612219},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_54.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_54_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_54_probability.npy', 'trueIMT_tuple': (0.7336385365380161, 8.05256637389463, 1.0, 1.0), 'imt_tuple': (0.7363134803480761, 8.039341651693492, 1.0, 0.8014981273408239), 'imt_diff': -0.0026749438100599487, 'ld_diff': 0.01322472220113724},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_117.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_117_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_117_probability.npy', 'trueIMT_tuple': (0.7318083118258699, 7.863067722929331, 1.0, 1.0), 'imt_tuple': (0.746853944530376, 7.896684414437043, 0.9962546816479401, 0.5056179775280899), 'imt_diff': -0.015045632704506096, 'ld_diff': -0.03361669150771274},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_112.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_112_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_112_probability.npy', 'trueIMT_tuple': (0.7671457274219249, 7.64189210579227, 1.0, 1.0), 'imt_tuple': (0.7709108794234798, 7.655277988531089, 0.8913857677902621, 0.850187265917603), 'imt_diff': -0.0037651520015549167, 'ld_diff': -0.013385882738818466},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_185.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_185_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_185_probability.npy', 'trueIMT_tuple': (0.8162802216172362, 7.1056362651334135, 1.0, 1.0), 'imt_tuple': (0.7547482324260744, 6.993258761304404, 0.38202247191011235, 0.3707865168539326), 'imt_diff': 0.06153198919116187, 'ld_diff': 0.11237750382900913},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_36.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_36_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_36_probability.npy', 'trueIMT_tuple': (0.7677088734872006, 7.644848622634968, 1.0, 1.0), 'imt_tuple': (0.7715101094278121, 7.639587378376975, 1.0, 0.6067415730337079), 'imt_diff': -0.003801235940611436, 'ld_diff': 0.005261244257993347},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_247.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_247_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_247_probability.npy', 'trueIMT_tuple': (0.6234026942602832, 7.204468399589311, 1.0, 1.0), 'imt_tuple': (0.621572469548137, 7.203833143357142, 1.0, 0.9213483146067416), 'imt_diff': 0.0018302247121461113, 'ld_diff': 0.0006352562321696453},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_208.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_208_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_208_probability.npy', 'trueIMT_tuple': (0.7986819070773683, 6.953727614025273, 1.0, 1.0), 'imt_tuple': (0.7779188702833448, 6.9787062548879515, 0.797752808988764, 0.7453183520599251), 'imt_diff': 0.02076303679402347, 'ld_diff': -0.024978640862678425},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_180.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_180_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_180_probability.npy', 'trueIMT_tuple': (0.7510960645615653, 7.357221769795365, 1.0, 1.0), 'imt_tuple': (0.764421456949213, 7.374447609772374, 0.5131086142322098, 0.4756554307116105), 'imt_diff': -0.013325392387647739, 'ld_diff': -0.01722583997700866},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_124.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_124_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_124_probability.npy', 'trueIMT_tuple': (0.7619366263181239, 7.69384233031396, 1.0, 1.0), 'imt_tuple': (0.7711122906477549, 7.7144544955719505, 0.8164794007490637, 0.8277153558052435), 'imt_diff': -0.009175664329631017, 'ld_diff': -0.020612165257990256},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_100.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_100_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_100_probability.npy', 'trueIMT_tuple': (0.7808020195048624, 7.354687612501625, 1.0, 1.0), 'imt_tuple': (0.7789396650898218, 7.3644811484855595, 0.9026217228464419, 0.8913857677902621), 'imt_diff': 0.001862354415040568, 'ld_diff': -0.009793535983934731},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_37.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_37_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_37_probability.npy', 'trueIMT_tuple': (0.7712285363951742, 7.640061881080124, 1.0, 1.0), 'imt_tuple': (0.7703838172972606, 7.634163512656845, 1.0, 0.5393258426966292), 'imt_diff': 0.0008447190979136154, 'ld_diff': 0.0058983684232787326},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_228.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_228_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_228_probability.npy', 'trueIMT_tuple': (0.6224171886460507, 7.310480646377477, 1.0, 1.0), 'imt_tuple': (0.6197422448359907, 7.303933225257102, 1.0, 0.9325842696629213), 'imt_diff': 0.0026749438100599487, 'ld_diff': 0.0065474211203753185},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_146.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_146_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_146_probability.npy', 'trueIMT_tuple': (0.766582581356649, 7.586844577911564, 1.0, 1.0), 'imt_tuple': (0.7764914676375677, 7.587633905593221, 0.38202247191011235, 0.45692883895131087), 'imt_diff': -0.009908886280918683, 'ld_diff': -0.0007893276816570705},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_207.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_207_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_207_probability.npy', 'trueIMT_tuple': (0.7831953902822844, 6.957106490416927, 1.0, 1.0), 'imt_tuple': (0.7781481278841585, 6.971362236666717, 0.8014981273408239, 0.7116104868913857), 'imt_diff': 0.005047262398125807, 'ld_diff': -0.014255746249790313},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_127.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_127_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_127_probability.npy', 'trueIMT_tuple': (0.7660194352913733, 7.664277161886982, 1.0, 1.0), 'imt_tuple': (0.7581799512473565, 7.689913869860896, 0.8164794007490637, 0.8164794007490637), 'imt_diff': 0.007839484044016798, 'ld_diff': -0.025636707973913708},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_155.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_155_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_155_probability.npy', 'trueIMT_tuple': (0.6170673010259308, 7.727771880746826, 1.0, 1.0), 'imt_tuple': (0.6067898853346478, 7.716751694814274, 1.0, 0.9775280898876404), 'imt_diff': 0.010277415691282932, 'ld_diff': 0.011020185932552273},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_250.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_250_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_250_probability.npy', 'trueIMT_tuple': (0.8472532552074039, 6.749587165362804, 1.0, 1.0), 'imt_tuple': (0.8721498732290403, 6.749974075069522, 0.9101123595505618, 0.5205992509363296), 'imt_diff': -0.02489661802163634, 'ld_diff': -0.00038690970671773073},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_135.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_135_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_135_probability.npy', 'trueIMT_tuple': (0.7755929184010615, 7.6128900834305675, 1.0, 1.0), 'imt_tuple': (0.7777160840012006, 7.6467100342336405, 0.602996254681648, 0.5917602996254682), 'imt_diff': -0.002123165600139143, 'ld_diff': -0.033819950803072985},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_183.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_183_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_183_probability.npy', 'trueIMT_tuple': (0.6163633684443359, 7.62598322944823, 1.0, 1.0), 'imt_tuple': (0.613969997666914, 7.622650531033927, 1.0, 0.9363295880149812), 'imt_diff': 0.002393370777421966, 'ld_diff': 0.003332698414302726},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_113.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_113_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_113_probability.npy', 'trueIMT_tuple': (0.7647523566445029, 7.655407611358888, 1.0, 1.0), 'imt_tuple': (0.7730046124471979, 7.6755888169866076, 0.8764044943820225, 0.8764044943820225), 'imt_diff': -0.008252255802694952, 'ld_diff': -0.0201812056277193},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_144.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_144_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_144_probability.npy', 'trueIMT_tuple': (0.7612326937365292, 7.595854914955976, 1.0, 1.0), 'imt_tuple': (0.746429997163566, 7.605994743824493, 0.49812734082397003, 0.4943820224719101), 'imt_diff': 0.014802696572963292, 'ld_diff': -0.01013982886851661},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_99.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_99_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_99_probability.npy', 'trueIMT_tuple': (0.7768599970479321, 7.351731095658927, 1.0, 1.0), 'imt_tuple': (0.7805452911515749, 7.365270854364912, 0.8913857677902621, 0.8913857677902621), 'imt_diff': -0.003685294103642822, 'ld_diff': -0.013539758705984895},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_165.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_165_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_165_probability.npy', 'trueIMT_tuple': (0.7713693229114931, 7.475623230019598, 1.0, 1.0), 'imt_tuple': (0.7744687756829728, 7.473361846601224, 0.49063670411985016, 0.4794007490636704), 'imt_diff': -0.003099452771479716, 'ld_diff': 0.0022613834183733417},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_157.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_157_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_157_probability.npy', 'trueIMT_tuple': (0.7684128060687954, 7.515606600654178, 1.0, 1.0), 'imt_tuple': (0.7717696845672751, 7.533080989338363, 0.599250936329588, 0.6254681647940075), 'imt_diff': -0.003356878498479765, 'ld_diff': -0.01747438868418527},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_120.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_120_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_120_probability.npy', 'trueIMT_tuple': (0.7634852779976323, 7.697502779738254, 1.0, 1.0), 'imt_tuple': (0.7698431970745958, 7.733850103944702, 0.8426966292134831, 0.8426966292134831), 'imt_diff': -0.006357919076963481, 'ld_diff': -0.036347324206448484},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_160.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_160_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_160_probability.npy', 'trueIMT_tuple': (0.7688351656177521, 7.499979297342775, 1.0, 1.0), 'imt_tuple': (0.7731835299960343, 7.516972922255175, 0.6254681647940075, 0.6853932584269663), 'imt_diff': -0.004348364378282232, 'ld_diff': -0.016993624912400307},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_109.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_109_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_109_probability.npy', 'trueIMT_tuple': (0.759120895991745, 7.558124128582499, 1.0, 1.0), 'imt_tuple': (0.7574384971217336, 7.57577148760551, 0.9737827715355806, 0.9138576779026217), 'imt_diff': 0.0016823988700114256, 'ld_diff': -0.01764735902301151},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_85.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_85_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_85_probability.npy', 'trueIMT_tuple': (0.7471540421046349, 8.093253677110805, 1.0, 1.0), 'imt_tuple': (0.739269997190774, 8.108462358568373, 1.0, 0.846441947565543), 'imt_diff': 0.007884044913860855, 'ld_diff': -0.015208681457567153},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_162.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_162_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_162_probability.npy', 'trueIMT_tuple': (0.6127029190200435, 7.753395026716874, 1.0, 1.0), 'imt_tuple': (0.6132660650853192, 7.752405536578594, 1.0, 0.7940074906367042), 'imt_diff': -0.0005631460652757436, 'ld_diff': 0.0009894901382798693},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_120.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_120_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_120_probability.npy', 'trueIMT_tuple': (0.7263176376894311, 7.850115363427989, 1.0, 1.0), 'imt_tuple': (0.7421905234954654, 7.891143370013655, 0.9962546816479401, 0.5617977528089888), 'imt_diff': -0.015872885806034298, 'ld_diff': -0.04102800658566608},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_165.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_165_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_165_probability.npy', 'trueIMT_tuple': (0.7686943791014332, 7.477171881699106, 1.0, 1.0), 'imt_tuple': (0.7838369288396014, 7.490816242721339, 0.6591760299625468, 0.6629213483146067), 'imt_diff': -0.015142549738168198, 'ld_diff': -0.013644361022232765},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_204.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_204_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_204_probability.npy', 'trueIMT_tuple': (0.7657378622587354, 6.962315591520728, 1.0, 1.0), 'imt_tuple': (0.7695952630329848, 6.976132429631047, 0.704119850187266, 0.6404494382022472), 'imt_diff': -0.003857400774249342, 'ld_diff': -0.013816838110319196},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_159.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_159_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_159_probability.npy', 'trueIMT_tuple': (0.7848848284781118, 7.622181993507619, 1.0, 1.0), 'imt_tuple': (0.7804535064682389, 7.619613121730401, 0.9925093632958801, 0.8202247191011236), 'imt_diff': 0.004431322009872951, 'ld_diff': 0.0025688717772176517},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_150.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_150_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_150_probability.npy', 'trueIMT_tuple': (0.7734811206562773, 7.5676976116921875, 1.0, 1.0), 'imt_tuple': (0.7635163607350014, 7.567137226146839, 0.5767790262172284, 0.5730337078651685), 'imt_diff': 0.009964759921275879, 'ld_diff': 0.0005603855453486517},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_143.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_143_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_143_probability.npy', 'trueIMT_tuple': (0.7688351656177521, 7.7198878358329655, 1.0, 1.0), 'imt_tuple': (0.7657378622587354, 7.719062761365236, 1.0, 0.48314606741573035), 'imt_diff': 0.003097303359016701, 'ld_diff': 0.000825074467729614},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_184.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_184_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_184_probability.npy', 'trueIMT_tuple': (0.7940359520388431, 7.108874355008749, 1.0, 1.0), 'imt_tuple': (0.7574739593857499, 7.015421673341397, 0.3970037453183521, 0.37453183520599254), 'imt_diff': 0.036561992653093234, 'ld_diff': 0.09345268166735199},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_49.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_49_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_49_probability.npy', 'trueIMT_tuple': (0.7610919072202103, 7.798024352389979, 1.0, 1.0), 'imt_tuple': (0.7579946038611935, 7.789319970400584, 1.0, 0.6704119850187266), 'imt_diff': 0.003097303359016701, 'ld_diff': 0.008704381989395493},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_102.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_102_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_102_probability.npy', 'trueIMT_tuple': (0.7168849410960619, 7.96189985738523, 1.0, 1.0), 'imt_tuple': (0.731526738793232, 7.987407432334418, 1.0, 0.7528089887640449), 'imt_diff': -0.014641797697170111, 'ld_diff': -0.025507574949187983},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_94.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_94_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_94_probability.npy', 'trueIMT_tuple': (0.7768599970479321, 7.372285927041492, 1.0, 1.0), 'imt_tuple': (0.7801698083561095, 7.3884095439084785, 0.9925093632958801, 0.9625468164794008), 'imt_diff': -0.003309811308177424, 'ld_diff': -0.016123616866986268},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_204.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_204_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_204_probability.npy', 'trueIMT_tuple': (0.6324130313046956, 7.4495777245005925, 1.0, 1.0), 'imt_tuple': (0.6277670762661705, 7.448770512235212, 1.0, 0.9700374531835206), 'imt_diff': 0.0046459550385251625, 'ld_diff': 0.0008072122653803859},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_130.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_130_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_130_probability.npy', 'trueIMT_tuple': (0.6146739302485087, 7.212634017535811, 1.0, 1.0), 'imt_tuple': (0.616222581928017, 7.2214401306612945, 1.0, 0.947565543071161), 'imt_diff': -0.0015486516795083505, 'ld_diff': -0.00880611312548396},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_148.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_148_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_148_probability.npy', 'trueIMT_tuple': (0.7840401093801982, 7.708906487560087, 1.0, 1.0), 'imt_tuple': (0.7789326286190034, 7.698088009962952, 0.9962546816479401, 0.5730337078651685), 'imt_diff': 0.005107480761194827, 'ld_diff': 0.010818477597135612},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_130.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_130_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_130_probability.npy', 'trueIMT_tuple': (0.7639076375465891, 7.6240122182197645, 1.0, 1.0), 'imt_tuple': (0.7628177557219821, 7.663362456428355, 0.651685393258427, 0.6479400749063671), 'imt_diff': 0.0010898818246070086, 'ld_diff': -0.039350238208590405},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_158.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_158_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_158_probability.npy', 'trueIMT_tuple': (0.6152370763137844, 7.74199131889504, 1.0, 1.0), 'imt_tuple': (0.6070714583672857, 7.731253744940301, 1.0, 0.9625468164794008), 'imt_diff': 0.008165617946498727, 'ld_diff': 0.010737573954738622},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_167.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_167_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_167_probability.npy', 'trueIMT_tuple': (0.6207277504502232, 7.751283228972089, 1.0, 1.0), 'imt_tuple': (0.6149555032811466, 7.748674214457476, 1.0, 0.7677902621722846), 'imt_diff': 0.00577224716907665, 'ld_diff': 0.0026090145146131505},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_130.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_130_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_130_probability.npy', 'trueIMT_tuple': (0.7739034802052341, 7.629221319323565, 1.0, 1.0), 'imt_tuple': (0.8021953815670421, 7.6930619707663634, 0.6816479400749064, 0.6554307116104869), 'imt_diff': -0.028291901361807925, 'ld_diff': -0.06384065144279827},
# ...
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_99.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_99_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_99_probability.npy', 'trueIMT_tuple': (0.7615142667691671, 7.343283904679791, 1.0, 1.0), 'imt_tuple': (0.7631366637667473, 7.359775955296449, 0.9438202247191011, 0.8951310861423221), 'imt_diff': -0.0016223969975801555, 'ld_diff': -0.016492050616657927},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_151.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_151_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_151_probability.npy', 'trueIMT_tuple': (0.7909386486798264, 7.6891963752754355, 1.0, 1.0), 'imt_tuple': (0.781758944397737, 7.6814558417782095, 0.9962546816479401, 0.5805243445692884), 'imt_diff': 0.009179704282089474, 'ld_diff': 0.007740533497226032},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_161.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_161_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_161_probability.npy', 'trueIMT_tuple': (0.7754521318847425, 7.499979297342775, 1.0, 1.0), 'imt_tuple': (0.786277449241445, 7.506059618535796, 0.5880149812734082, 0.6367041198501873), 'imt_diff': -0.010825317356702557, 'ld_diff': -0.006080321193021376},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_238.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_238_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_238_probability.npy', 'trueIMT_tuple': (0.6276262897498515, 7.2612053656658455, 1.0, 1.0), 'imt_tuple': (0.6225579751623695, 7.25368135583522, 1.0, 0.947565543071161), 'imt_diff': 0.005068314587481915, 'ld_diff': 0.007524009830625289},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_216.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_216_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_216_probability.npy', 'trueIMT_tuple': (0.618897525738077, 7.371159634910941, 1.0, 1.0), 'imt_tuple': (0.6163633684443359, 7.363190543448447, 1.0, 0.9176029962546817), 'imt_diff': 0.0025341572937410684, 'ld_diff': 0.007969091462494582},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_116.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_116_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_116_probability.npy', 'trueIMT_tuple': (0.7654562892260975, 7.682720195524764, 1.0, 1.0), 'imt_tuple': (0.7668670632016076, 7.705017987249858, 0.9063670411985019, 0.9063670411985019), 'imt_diff': -0.001410773975510038, 'ld_diff': -0.022297791725093496},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_181.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_181_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_181_probability.npy', 'trueIMT_tuple': (0.7698206712319848, 7.366654466388735, 1.0, 1.0), 'imt_tuple': (0.7509872403894916, 7.369118230424316, 0.6928838951310862, 0.6666666666666666), 'imt_diff': 0.018833430842493226, 'ld_diff': -0.0024637640355811286},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_246.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_246_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_246_probability.npy', 'trueIMT_tuple': (0.6321314582720577, 7.216998399541698, 1.0, 1.0), 'imt_tuple': (0.6259368515540241, 7.214364829728271, 1.0, 0.9176029962546817), 'imt_diff': 0.006194606718033624, 'ld_diff': 0.0026335698134269947},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_196.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_196_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_196_probability.npy', 'trueIMT_tuple': (0.7585577499264693, 6.993147838594577, 1.0, 1.0), 'imt_tuple': (0.758064997119353, 6.953227519590005, 0.6292134831460674, 0.6104868913857678), 'imt_diff': 0.0004927528071162479, 'ld_diff': 0.03992031900457249},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_105.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_105_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_105_probability.npy', 'trueIMT_tuple': (0.7827730307333276, 7.4233914324652694, 1.0, 1.0), 'imt_tuple': (0.7885583598353365, 7.439645705062679, 0.846441947565543, 0.8426966292134831), 'imt_diff': -0.005785329102008907, 'ld_diff': -0.016254272597409525},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_185.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_185_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_185_probability.npy', 'trueIMT_tuple': (0.6217132560644559, 7.606836263228853, 1.0, 1.0), 'imt_tuple': (0.6169265145096119, 7.606395205470698, 1.0, 0.9588014981273408), 'imt_diff': 0.004786741554844043, 'ld_diff': 0.0004410577581550612},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_141.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_141_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_141_probability.npy', 'trueIMT_tuple': (0.7651747161934597, 7.722281206610387, 1.0, 1.0), 'imt_tuple': (0.7633444914813133, 7.719080724092151, 1.0, 0.5468164794007491), 'imt_diff': 0.0018302247121463333, 'ld_diff': 0.0032004825182365693},
#        {'image_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_140.npy', 'mask_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_140_mask.npy', 'result_file': 'interobserver_good_resultateT1_SAPCIMT-20100831-6302121-1959-M-63--50000044-634-RCCAH-SC-20110311-ClipResult.h5_140_probability.npy', 'trueIMT_tuple': (0.6477587615834606, 7.221785141096542, 1.0, 1.0), 'imt_tuple': (0.64482394491809, 7.211383502008507, 0.9962546816479401, 0.9550561797752809), 'imt_diff': 0.002934816665370543, 'ld_diff': 0.01040163908803482},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_71.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_71_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_71_probability.npy', 'trueIMT_tuple': (0.7281478624015775, 8.222214126058956, 1.0, 1.0), 'imt_tuple': (0.7278662893689396, 8.220932968760454, 1.0, 0.7490636704119851), 'imt_diff': 0.0002815730326378718, 'ld_diff': 0.001281157298501867},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_61.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_61_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6101247-1953-M-61-1-50000041-611-RCCAH-SC-20101214-ClipResult.h5_61_probability.npy', 'trueIMT_tuple': (0.7512368510778842, 8.181526822842782, 1.0, 1.0), 'imt_tuple': (0.7427265489017769, 8.170632575955487, 0.9775280898876404, 0.9625468164794008), 'imt_diff': 0.008510302176107265, 'ld_diff': 0.010894246887295012},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_163.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_163_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_163_probability.npy', 'trueIMT_tuple': (0.7865742666739391, 6.761835592282552, 1.0, 1.0), 'imt_tuple': (0.7889503478791816, 6.771368599268799, 0.6404494382022472, 0.599250936329588), 'imt_diff': -0.002376081205242464, 'ld_diff': -0.009533006986246484},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_162.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_162_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_162_probability.npy', 'trueIMT_tuple': (0.7931912329409295, 6.756626491178751, 1.0, 1.0), 'imt_tuple': (0.7972036486560193, 6.756979785644231, 0.6666666666666666, 0.5955056179775281), 'imt_diff': -0.004012415715089812, 'ld_diff': -0.0003532944654800474},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_111.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_111_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_111_probability.npy', 'trueIMT_tuple': (0.7577130308285557, 7.614438735110076, 1.0, 1.0), 'imt_tuple': (0.754286495188186, 7.626071221020929, 0.9625468164794008, 0.9588014981273408), 'imt_diff': 0.0034265356403696545, 'ld_diff': -0.011632485910853418},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_104.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_104_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_104_probability.npy', 'trueIMT_tuple': (0.7910794351961453, 7.401287949403195, 1.0, 1.0), 'imt_tuple': (0.7931327242588229, 7.413366335465572, 0.8651685393258427, 0.8651685393258427), 'imt_diff': -0.0020532890626775435, 'ld_diff': -0.012078386062376545},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_134.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_134_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_134_probability.npy', 'trueIMT_tuple': (0.7765784240152942, 7.6100743531041894, 1.0, 1.0), 'imt_tuple': (0.7776853263861131, 7.647774970938455, 0.6254681647940075, 0.6292134831460674), 'imt_diff': -0.0011069023708188963, 'ld_diff': -0.03770061783426559},
#        {'image_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_175.npy', 'mask_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_175_mask.npy', 'result_file': 'interobserver_medium_resultateT1_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-SC-20110311-ClipResult.h5_175_probability.npy', 'trueIMT_tuple': (0.7847440419617928, 7.426488735824286, 1.0, 1.0), 'imt_tuple': (0.789389997000318, 7.465892454388229, 0.5355805243445693, 0.5430711610486891), 'imt_diff': -0.0046459550385251625, 'ld_diff': -0.03940371856394265},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_122.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_122_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100902-6701909-1946-M-67-2-50000045-671-LCCAE-CM-20110309-ClipResult.h5_122_probability.npy', 'trueIMT_tuple': (0.7563051656653662, 7.709610420141682, 1.0, 1.0), 'imt_tuple': (0.8179518309529183, 7.768435102058893, 0.8576779026217228, 0.8539325842696629), 'imt_diff': -0.06164666528755214, 'ld_diff': -0.05882468191721113},
#        {'image_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_165.npy', 'mask_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_165_mask.npy', 'result_file': 'interobserver_medium_resultateT0_SAPCIMT-20100901-6601595-1947-F-66-2-50000047-664-LCCAE-CM-20110309-ClipResult.h5_165_probability.npy', 'trueIMT_tuple': (0.7929096599082915, 6.8074504235698905, 1.0, 1.0), 'imt_tuple': (0.8003740878676694, 6.826922281750003, 0.5767790262172284, 0.5355805243445693), 'imt_diff': -0.007464427959377851, 'ld_diff': -0.0194718581801121}],
#       dtype=object)

# %%
ldhole = []
imthole = []
for res in resultsProb:
    if (res['imt_tuple'][3] < 1.0):
        ldhole.append(res)
    if (res['imt_tuple'][2] < 1.0):
        imthole.append(res)

# %%
len(ldhole)
# Out:
# 106

# %%
len(imthole)
# Out:
# 75

# %%
plotlist = []
for imt in resultsAver:
    plotlist.append(imt['ld_diff'])

# %%
plotlist = sorted(plotlist, key = lambda i: abs(i), reverse=True)

# %%
len(plotlist)
# Out:
# 107

# %%
plotlist
# Out:
# [0.11538500456765632,
#  0.10394972432409233,
#  0.09669710010162458,
#  -0.05779102860306118,
#  -0.05228488099490747,
#  -0.04854255088806081,
#  0.04401391155985568,
#  -0.04238768336922938,
#  0.040602316233762537,
#  -0.039524406591379346,
#  -0.03724991814241285,
#  -0.036142181763662684,
#  -0.034282670711501595,
#  -0.03186521785644025,
#  -0.0316545817047329,
#  -0.031389135960622205,
#  -0.027429651214772477,
#  -0.027221781028131886,
#  -0.027003694346488416,
#  -0.02591656737287007,
#  0.02518436132752111,
#  -0.024847402816371655,
#  -0.02375216726633589,
#  -0.022399134746344807,
#  -0.021214534571865507,
#  -0.02066607787090824,
#  -0.020408227241606625,
#  -0.02022008897408334,
#  -0.0194096532559227,
#  0.018368753635306767,
#  -0.017449450108678377,
#  -0.01733924427008482,
#  -0.016683202183795487,
#  0.01621671551778281,
#  -0.015724707936064952,
#  -0.0157056489460059,
#  -0.015684823094336053,
#  -0.015580116621867646,
#  -0.015343504404989439,
#  -0.014295720882154583,
#  -0.014179296538189057,
#  0.013576030611018197,
#  -0.01344001134772288,
#  -0.013146038189538523,
#  -0.012880097395621348,
#  0.012811572985024,
#  0.012767680718171803,
#  -0.012741179726864615,
#  0.012536526479632215,
#  -0.012352256975534104,
#  -0.011849531790177892,
#  0.011534556466413548,
#  -0.011362015677516268,
#  -0.011001242019749391,
#  -0.010932274115760698,
#  0.010818477597135612,
#  -0.010751470289201315,
#  0.010156048004800411,
#  -0.00985853235260592,
#  0.009784241367649216,
#  -0.009665602682094487,
#  0.009544381986203554,
#  0.009421192636783537,
#  -0.009337325082315218,
#  0.00928533638757223,
#  0.008153966648595912,
#  0.008080597517813537,
#  -0.007783483116490686,
#  -0.007602471881223316,
#  0.007602471881222428,
#  0.007355377179112388,
#  0.007117540547235457,
#  0.006746074639098154,
#  0.006527952856672847,
#  0.006438050069168533,
#  0.0064204517546286866,
#  0.006396457265527289,
#  0.006186816159817532,
#  0.005556562226075812,
#  0.005094815578789991,
#  -0.005049289382573541,
#  0.004357472238215365,
#  0.0043128747438192505,
#  0.003803413051688409,
#  -0.003740562253662816,
#  0.003554141238501174,
#  0.0032064129091642357,
#  0.0029430167657906736,
#  0.0027042743342926556,
#  0.002621719639255282,
#  0.0025688717772176517,
#  -0.002536813643104985,
#  -0.002118411876423032,
#  0.0020378651607950715,
#  0.001845007296358503,
#  -0.001732536108985272,
#  -0.0017060013153935571,
#  0.0016934606677230235,
#  -0.0016600850225412245,
#  0.0015088193968422203,
#  0.001283409882763209,
#  0.0007765784240154616,
#  0.0005296804179542036,
#  -0.0003405069231900981,
#  0.00029422182121319196,
#  -7.437778220609204e-05,
#  3.327681294873486e-05]

# %%
plotlist[0]
# Out:
# 0.11538500456765632

# %%
plotlist[106]
# Out:
# 3.327681294873486e-05

# %%
fig = plt.figure(figsize=(20,20))
plt.hist(plotlist,100, color='orangered')

plt.xticks(fontsize=32)
plt.yticks(fontsize=32)
plt.title("LD Differences",fontsize=36)
plt.xlabel("Values",fontsize=36)
plt.ylabel("Frequency",fontsize=36)
# Out:
# Text(0, 0.5, 'Frequency')
